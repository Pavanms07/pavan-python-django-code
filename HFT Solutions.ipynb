# %%
import datetime
import time

books=["a","b","c","d"]
now = datetime.date.today()
d=now.strftime("%d/%m/%y")
t=now.strftime("%I:%M:%S:%p")

Customer_name=str(input("Customer Name: ")) 
Email=str(input("@Email: "))
Ph=int(input("Mobile_no: "))


                                            #enetr 1 for buy, 2 for sell"
option=int(input("Welcome------"))
rate={"a":100,"b":30,"c":100,"d":123}
value=rate.values()
total=(sum(value))
if option==1:
    buy=1
    print("Available books for Buy")
    print("----------------------------------------------------")


    rate={"a":100,"b":30,"c":100,"d":123}
    if buy==2:
        print(sell)
    else:
      
        print("       ","Name of books",   "       Rate ")
        print("----------------------------------------------------")

        for i in books:
            print("          ",i,"          :     ",rate[i])
           
elif option==2:

    sell=2
    print("Available books for Sell")
    print("----------------------------------------------------")

    rate={"a":100,"b":30,"c":100,"d":220}
    if sell==1:
        print(buy)
    else:
        
        print("       ","Name of books",   "       Rate   ")
        print("----------------------------------------------------")
        for i in books:
            print("          ",i,"          :     ",rate[i])
print("----------------------------------------------------")
print("   total amount        :","    ",total)
print("\n")
print("Date  ","      Time")
print(d,"   ", t)
# Out:
# Customer Name: Pavan M S
# @Email: pavanmshsn@gmail.com
# Mobile_no: 8197206604
# Welcome------1
# Available books for Buy
# ----------------------------------------------------
#         Name of books        Rate
# ----------------------------------------------------
#            a           :      100
#            b           :      30
#            c           :      100
#            d           :      123
# ----------------------------------------------------
#    total amount        :      353
#
#
# Date         Time
# 05/01/21     12:00:00:AM

# %%
 import datetime
import time

books=["a","b","c","d"]
now = datetime.date.today()
d=now.strftime("%d/%m/%y")
t=now.strftime("%I:%M:%S:%p")

Customer_name=str(input("Customer Name: ")) 
Email=str(input("@Email: "))
Ph=int(input("Mobile_no: "))


                                            #enetr 1 for buy, 2 for sell"
option=int(input("Welcome------"))
rate={"a":100,"b":30,"c":100,"d":123}
value=rate.values()
total=(sum(value))
if option==1:
    buy=1
    print("Available books for Buy")
    print("----------------------------------------------------")


    rate={"a":100,"b":30,"c":100,"d":123}
    if buy==2:
        print(sell)
    else:
      
        print("       ","Name of books",   "       Rate ")
        print("----------------------------------------------------")

        for i in books:
            print("          ",i,"          :     ",rate[i])
           
elif option==2:

    sell=2
    print("Available books for Sell")
    print("----------------------------------------------------")

    rate={"a":100,"b":30,"c":100,"d":220}
    if sell==1:
        print(buy)
    else:
        
        print("       ","Name of books",   "       Rate   ")
        print("----------------------------------------------------")
        for i in books:
            print("          ",i,"          :     ",rate[i])
print("----------------------------------------------------")
print("   total amount        :","    ",total)
print("\n")
print("Date  ","      Time")
print(d,"   ", t)
# Out:
# Customer Name: Pavan M S
# @Email: pavanmshsn@gmail.com
# Mobile_no: 8197206604
# Welcome------2
# Available books for Sell
# ----------------------------------------------------
#         Name of books        Rate
# ----------------------------------------------------
#            a           :      100
#            b           :      30
#            c           :      100
#            d           :      220
# ----------------------------------------------------
#    total amount        :      353
#
#
# Date         Time
# 05/01/21     12:00:00:AM
