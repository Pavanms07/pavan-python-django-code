# %%
import bs4 as bs
import urllib.request

source = urllib.request.urlopen('https://stackoverflow.com/questions').read()
soup = bs.BeautifulSoup(source,'lxml')

# title of the page
print(soup.title)

# get attributes:
print(soup.title.name)

# get values:
print(soup.title.string)

# beginning navigation:
print(soup.title.parent.name)

# getting specific values:
print(soup.p)

print(soup.find_all('p'))

for paragraph in soup.find_all('p'):
    print(paragraph.string)
    print(str(paragraph.text))

for url in soup.find_all('a'):
    print(url.get('href'))

nav = soup.nav
for url in nav.find_all('a'):
    print(url.get('href'))
          
body = soup.body
for paragraph in body.find_all('p'):
    print(paragraph.text)

for div in soup.find_all('div', class_='body'):
    print(div.text)

soup = bs.BeautifulSoup(source,'xml')
for url in soup.find_all('loc'):
    print(url.text)

soup = bs.BeautifulSoup(source,'lxml')
js_test = soup.find('p', class_='jstest')

print("it will be contunued")
# Out:
# <title>Newest Questions - Stack Overflow</title>
# title
# Newest Questions - Stack Overflow
# head
# <p class="mb0 lh-lg">
#                     By using our site, you acknowledge that you have read and understand our <a class="s-link s-link__inherit td-underline fc-white" href="https://stackoverflow.com/legal/cookie-policy" target="_blank">Cookie Policy</a>, <a class="s-link s-link__inherit td-underline fc-white" href="https://stackoverflow.com/legal/privacy-policy" target="_blank">Privacy Policy</a>, and our <a class="s-link s-link__inherit td-underline fc-white" href="https://stackoverflow.com/legal/terms-of-service/public" target="_blank">Terms of Service</a>.
#                 </p>
# [<p class="mb0 lh-lg">
#                     By using our site, you acknowledge that you have read and understand our <a class="s-link s-link__inherit td-underline fc-white" href="https://stackoverflow.com/legal/cookie-policy" target="_blank">Cookie Policy</a>, <a class="s-link s-link__inherit td-underline fc-white" href="https://stackoverflow.com/legal/privacy-policy" target="_blank">Privacy Policy</a>, and our <a class="s-link s-link__inherit td-underline fc-white" href="https://stackoverflow.com/legal/terms-of-service/public" target="_blank">Terms of Service</a>.
#                 </p>, <p class="mb2"><strong>Teams</strong></p>, <p class="mb16 fs-caption fc-medium">Q&amp;A for Work</p>, <p class="mb8 fs-caption fc-medium">
#
#                             Stack Overflow for Teams is a private, secure spot for you and
#                             your coworkers to find and share information.
#                                         </p>, <p class="mt-auto mb24">
# site design / logo © 2020 Stack Exchange Inc; user contributions licensed under <a href="https://stackoverflow.com/help/licensing">cc by-sa</a>.                    <span id="svnrev">rev 2020.10.26.37891</span>
# </p>]
# None
#
#                     By using our site, you acknowledge that you have read and understand our Cookie Policy, Privacy Policy, and our Terms of Service.
#
# Teams
# Teams
# Q&A for Work
# Q&A for Work
#
#
#                             Stack Overflow for Teams is a private, secure spot for you and
#                             your coworkers to find and share information.
#
#
#
#                             Stack Overflow for Teams is a private, secure spot for you and
#                             your coworkers to find and share information.
#
# None
#
# site design / logo © 2020 Stack Exchange Inc; user contributions licensed under cc by-sa.                    rev 2020.10.26.37891
#
# #
# https://stackoverflow.com
# /company
# #
# /teams
# /questions
# /teams
# /jobs?so_source=ProductsMenu&so_medium=StackOverflow
# https://stackoverflow.com/talent
# https://stackoverflow.com/advertising
# /company
# #
# https://stackoverflow.com/users/login?ssrc=head&returnurl=https%3a%2f%2fstackoverflow.com%2fquestions
# https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent
# https://stackoverflow.com
# https://stackoverflow.com
# https://stackoverflow.com/help
# https://chat.stackoverflow.com/?tab=site&host=stackoverflow.com
# https://meta.stackoverflow.com
# https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent
# https://stackoverflow.com/users/login?ssrc=site_switcher&returnurl=https%3a%2f%2fstackoverflow.com%2fquestions
# https://stackexchange.com/sites
# https://stackoverflow.blog
# https://stackoverflow.com/legal/cookie-policy
# https://stackoverflow.com/legal/privacy-policy
# https://stackoverflow.com/legal/terms-of-service/public
# None
# /
# /questions
# /tags
# /users
# /jobs?so_medium=StackOverflow&so_source=SiteNav
# /jobs/companies?so_medium=StackOverflow&so_source=SiteNav
# javascript:void(0)
# https://stackoverflow.com/teams
# https://stackoverflow.com/teams
# /questions/ask
# /questions?tab=Newest
# /questions?tab=Active
# /questions?tab=Bounties
# /questions?tab=Unanswered
# /questions?tab=Bounties
# /questions?tab=Unanswered
# /questions?tab=Frequent
# /questions?tab=Votes
# /questions/64550913/is-there-a-method-to-write-the-entire-sheet-with-the-list-of-dictionary-get-back
# /questions/tagged/gspread
# /users/14527466/walker
# /users/14527466/walker
# /questions/64550910/restrcit-file-type-in-file-upload
# /questions/tagged/drupal
# /questions/tagged/drupal-8
# /questions/tagged/drupal-modules
# /users/1699294/axysharma
# /users/1699294/axysharma
# /questions/64550908/vector-of-hex-to-string
# /questions/tagged/c%2b%2b
# /questions/tagged/hex
# /users/10894585/edutox
# /users/10894585/edutox
# /questions/64550907/elixir-phoenix-liveview-collapsible-collapses-on-update
# /questions/tagged/elixir
# /questions/tagged/phoenix-framework
# /questions/tagged/phoenix-live-view
# /users/2831651/joe-eifert
# /users/2831651/joe-eifert
# /questions/64550906/enable-button-if-monaco-editor-does-not-contain-error-angular-6
# /questions/tagged/javascript
# /questions/tagged/angular
# /questions/tagged/angular6
# /questions/tagged/monaco-editor
# /questions/tagged/ngx-monaco-editor
# /users/5850635/kavya-shree
# /users/5850635/kavya-shree
# /questions/64550905/python-program-glitches-out-after-a-few-second-tkinter
# /questions/tagged/python
# /questions/tagged/tkinter
# /users/14355670/venum
# /users/14355670/venum
# /questions/64550904/why-do-i-get-a-bad-request-with-this-jquery-post
# /questions/tagged/javascript
# /questions/tagged/jquery
# /questions/tagged/asp.net-mvc
# /users/8741/profk
# /users/8741/profk
# /questions/64550903/how-do-data-centers-manage-last-level-cache-among-virtual-machines
# /questions/tagged/virtual-machine
# /questions/tagged/allocation
# /questions/tagged/llc
# /users/14527456/hyeongtak-ji
# /users/14527456/hyeongtak-ji
# /questions/64550901/select-and-combine-2-arrays-in-xslt
# /questions/tagged/xslt
# /questions/tagged/xslt-2.0
# /questions/tagged/xslt-3.0
# /users/12192710/prateek-naik
# /users/12192710/prateek-naik
# /questions/64550900/how-to-generate-a-ltpa-token-from-the-application-that-has-been-deployed-in-web
# /questions/tagged/websphere
# /questions/tagged/ibm-mobilefirst
# /questions/tagged/websphere-9
# /users/14272554/abrar-ahmed
# /users/14272554/abrar-ahmed
# /questions/64550899/is-it-possible-to-set-root-password-at-runtime
# /questions/tagged/embedded-linux
# /questions/tagged/root
# /questions/tagged/yocto
# /users/11477952/adelegoldberg
# /users/11477952/adelegoldberg
# /questions/64550898/generate-english-slug-from-a-persianfarsi-title-in-node-js-and-mongo
# /questions/tagged/javascript
# /questions/tagged/node.js
# /questions/tagged/mongodb
# /questions/tagged/mongoose
# /questions/tagged/backend
# /users/14262994/alee-stvr
# /users/14262994/alee-stvr
# /questions/64550897/how-to-use-special-characters-and-colours-in-error-messages-in-r
# /questions/tagged/r
# /questions/tagged/error-handling
# /questions/tagged/warnings
# /users/14448369/kezrael
# /users/14448369/kezrael
# /questions/64550892/os-data-hub-not-working-on-ipad-or-iphone
# /questions/tagged/openlayers-6
# /users/14527396/allan-stead
# /users/14527396/allan-stead
# /questions/64550891/how-to-change-soap-xml-namespace-prefix-in-springboot
# /questions/tagged/spring
# /questions/tagged/spring-boot
# /questions/tagged/soap
# /questions/tagged/jaxb
# /questions/tagged/jax-ws
# /users/3480525/praveesh-p
# /users/3480525/praveesh-p
# /questions/64550890/keycloak-login-page-with-laravel
# /questions/tagged/laravel
# /questions/tagged/keycloak
# /users/7323416/p-james
# /users/7323416/p-james
# /questions/64550889/cannot-succeed-with-stencil-test-in-sharpgl
# /questions/tagged/c%23
# /questions/tagged/wpf
# /questions/tagged/opengl
# /questions/tagged/sharpgl
# /users/14405249/aris-theo
# /users/14405249/aris-theo
# /questions/64550888/nested-grouping-mysql
# /questions/tagged/mysql
# /questions/tagged/sql
# /questions/tagged/group-by
# /users/7908852/arsenal88
# /users/7908852/arsenal88
# /questions/64550883/optimal-way-to-add-dynamic-fields-or-preload-initial-values-for-django-models
# /questions/tagged/python
# /questions/tagged/django
# /users/2627114/jcf
# /users/2627114/jcf
# /questions/64550882/trouble-with-c-sharp-marshalling-information-in-mac-os-c-sharp-information
# /questions/tagged/c%23
# /questions/tagged/xcode
# /questions/tagged/macos
# /questions/tagged/visual-studio
# /users/14527374/user14527374
# /users/14527374/user14527374
# /questions/64550880/i-make-some-changes-in-css-of-react-nice-ticker-package-but-when-i-deploy-code-t
# /questions/tagged/css
# /questions/tagged/reactjs
# /questions/tagged/react-native
# /questions/tagged/sass
# /questions/tagged/react-redux
# /users/10794368/deeno-james
# /users/10794368/deeno-james
# /questions/64550879/expo-button-not-doing-anything-after-click
# /questions/tagged/reactjs
# /questions/tagged/react-native
# /questions/tagged/expo
# /users/14526796/softador-eood
# /users/14526796/softador-eood
# /questions/64550876/return-meaningfull-async-actionresults-in-net-core
# /questions/tagged/postman
# /questions/tagged/asp.net-core-3.1
# /users/4704225/axelrotter
# /users/4704225/axelrotter
# /questions/64550873/property-classlist-does-not-exist-on-type-globaleventhandlers-in-typescript
# /questions/tagged/typescript
# /users/9648823/jobayer-hossain
# /users/9648823/jobayer-hossain
# /questions/64550869/how-to-show-stringparameterdefinition-only-if-specific-value-was-selected-by-cas
# /questions/tagged/jenkins
# /questions/tagged/jenkins-pipeline
# /questions/tagged/jenkins-plugins
# /questions/tagged/jenkins-groovy
# /users/1161594/user22999299
# /users/1161594/user22999299
# /questions/64550868/spring-boot-app-web-server-failed-to-start-port-8092-was-already-in-use
# /questions/tagged/java
# /questions/tagged/spring
# /questions/tagged/spring-boot
# /users/11572712/tobitor
# /users/11572712/tobitor
# /questions/64550867/callback-function-ajax-js
# /questions/tagged/javascript
# /questions/tagged/ajax
# /questions/tagged/asynchronous
# /users/13804710/arbi-dwi-wijaya
# /users/13804710/arbi-dwi-wijaya
# /questions/64550865/react-native-android-fatal-exception-java-lang-outofmemoryerror
# /questions/tagged/java
# /questions/tagged/android
# /questions/tagged/react-native
# /questions/tagged/error-handling
# /questions/tagged/out-of-memory
# /users/10106073/jocoders
# /users/10106073/jocoders
# /questions/64550864/calculate-a-3d-trajectory-by-start-point-end-point-and-height
# /questions/tagged/c%23
# /questions/tagged/game-physics
# /users/12420682/roee-herzovich
# /users/12420682/roee-herzovich
# /questions/64550863/declare-variable-in-sql-with-entity-framework-core-for-executesqlcommand
# /questions/tagged/c%23
# /questions/tagged/sql-server
# /questions/tagged/entity-framework-core
# /questions/tagged/sqlparameter
# /users/12649102/thet
# /users/12649102/thet
# /questions/64550862/how-to-remove-icons-in-v-expansion-panels-vuetify
# /questions/tagged/vue.js
# /questions/tagged/vuetify.js
# /users/14527441/jenny-kim
# /users/14527441/jenny-kim
# /questions/64550860/from-a-list-of-list-how-do-i-find-list-with-n-elements-in-common
# /questions/tagged/python
# /questions/tagged/list
# /questions/tagged/subset
# /users/14527227/bux
# /users/14527227/bux
# /questions/64550858/running-powershell-script-issue-when-full-code-is-running
# /questions/tagged/powershell
# /users/7456138/ash15
# /users/7456138/ash15
# /questions/64550854/is-it-okay-to-post-google-fit-data-on-sns-such-as-twitter
# /questions/tagged/google-fit
# /users/14527444/hiroaki-t
# /users/14527444/hiroaki-t
# /questions/64550851/how-to-set-up-the-proxy-configuration-at-jre-level
# /questions/tagged/java
# /questions/tagged/spring-boot
# /questions/tagged/proxy
# /questions/tagged/jvm
# /questions/tagged/properties-file
# /users/10244943/sithaara
# /users/10244943/sithaara
# /questions/64550849/how-to-get-rid-of-a-bootstrap-4-navbar-style
# /questions/tagged/css
# /questions/tagged/twitter-bootstrap
# /users/7023030/truncatus
# /users/7023030/truncatus
# /questions/64550845/r-panel-data-create-new-variable-based-on-ifelse-statement-and-previous-row
# /questions/tagged/r
# /questions/tagged/lag
# /questions/tagged/panel-data
# /users/14095504/chuesker
# /users/14095504/chuesker
# /questions/64550844/getting-following-error-while-running-oracle-oracle-apex-20-2-application-forbid
# /questions/tagged/oracle
# /questions/tagged/oracle-apex
# /users/9518030/farooq
# /users/9518030/farooq
# /questions/64550843/assert-asserttruecurrent-url-containsdashboard-not-working
# /questions/tagged/selenium
# /questions/tagged/maven
# /questions/tagged/automation
# /questions/tagged/ui-automation
# /questions/tagged/serenity-bdd
# /users/14439648/francis-dayao
# /users/14439648/francis-dayao
# /questions/64550840/how-to-send-javascript-value-as-form-action
# /questions/tagged/javascript
# /questions/tagged/php
# /questions/tagged/jquery
# /questions/tagged/ajax
# /questions/tagged/laravel
# /users/14526731/arefeh
# /users/14526731/arefeh
# /questions/64550838/module-system-using-2-dbs-and-js-for-toggle-display
# /questions/tagged/php
# /questions/tagged/mysql
# /questions/tagged/database
# /questions/tagged/phpmyadmin
# /users/11472883/steven123452
# /users/11472883/steven123452
# /questions/64550833/android-app-widget-onreceived-is-not-getting-called-on-samsung-s10-plus
# /questions/tagged/java
# /questions/tagged/android
# /questions/tagged/kotlin
# /questions/tagged/android-widget
# /users/6742601/fazal-hussain
# /users/6742601/fazal-hussain
# /questions/64550831/android-studio-my-app-is-working-fine-in-emulator-but-when-i-build-and-run-it-i
# /questions/tagged/java
# /questions/tagged/android
# /questions/tagged/android-studio
# /users/14527382/mike-andrey-ferrolino
# /users/14527382/mike-andrey-ferrolino
# /questions/64550830/i-cant-download-token-json-in-ezgmail
# /questions/tagged/python
# /questions/tagged/email
# /questions/tagged/google-apps-script
# /users/14203032/madcodererrr
# /users/14203032/madcodererrr
# /questions/64550829/unknown-data-format-and-how-to-handle-it-in-php-data-format-close-to-json
# /questions/tagged/php
# /questions/tagged/dataformat
# /users/8943866/supremedev
# /users/8943866/supremedev
# /questions/64550828/extract-variable-items-on-single-line-using-grep
# /questions/tagged/perl
# /questions/tagged/grep
# /users/7796520/rosand-liu
# /users/7796520/rosand-liu
# /questions/64550825/how-to-quickly-to-check-is-mobile-connect-to-a-specific-ssid-quickly-on-iphone
# /questions/tagged/ios
# /questions/tagged/xamarin
# /questions/tagged/networking
# /questions/tagged/xamarin.ios
# /users/12672987/cc-wang
# /users/12672987/cc-wang
# /questions/64550824/fabris-js-know-canvas-activity
# /questions/tagged/fabricjs
# /users/1144596/user1144596
# /users/1144596/user1144596
# /questions/64550823/trying-to-replicate-aes-decryption-method-used-in-java-for-python
# /questions/tagged/java
# /questions/tagged/python
# /questions/tagged/encryption
# /questions/tagged/aes
# /users/1864177/endauriel
# /users/1864177/endauriel
# /questions/64550822/split-one-row-of-data-into-multiple-in-pandas
# /questions/tagged/python
# /questions/tagged/pandas
# /users/6370335/nurbek-kuantyrov
# /users/6370335/nurbek-kuantyrov
# /questions?tab=newest&pagesize=15
# /questions?tab=newest&pagesize=30
# /questions?tab=newest&pagesize=50
# /questions?tab=newest&page=2
# /questions?tab=newest&page=3
# /questions?tab=newest&page=4
# /questions?tab=newest&page=5
# /questions?tab=newest&page=406693
# /questions?tab=newest&page=2
# https://stackoverflow.blog/2020/10/27/podcast-281-the-story-behind-stack-overflow-in-russian/
# https://stackoverflow.blog/2020/10/23/adrian-cockcroft-aws-failover-chaos-engineering-fault-tolerance-distaster-recovery/
# https://meta.stackoverflow.com/questions/357338/when-is-a-closeable-question-also-a-very-low-quality-question
# /questions/tagged/javascript
# /questions/tagged/java
# /questions/tagged/python
# /questions/tagged/c%23
# /questions/tagged/php
# /questions/tagged/android
# /questions/tagged/html
# /questions/tagged/jquery
# /questions/tagged/c%2b%2b
# /questions/tagged/css
# /questions/tagged/ios
# /questions/tagged/mysql
# /questions/tagged/sql
# /questions/tagged/r
# /questions/tagged/asp.net
# /questions/tagged/node.js
# /questions/tagged/arrays
# /questions/tagged/c
# /questions/tagged/ruby-on-rails
# /questions/tagged/json
# /questions/tagged/.net
# /questions/tagged/sql-server
# /questions/tagged/objective-c
# /questions/tagged/swift
# /questions/tagged/angularjs
# #
# https://stackexchange.com/questions?tab=hot
# https://russian.stackexchange.com/questions/22963/why-is-max-verstappens-last-name-transliterated-with-a-%d0%a4-f-instead-of-a-%d0%92
# https://puzzling.stackexchange.com/questions/104207/chess-bloodshed
# https://pm.stackexchange.com/questions/30518/does-the-scrum-master-also-estimate-user-stories
# https://physics.stackexchange.com/questions/589693/how-does-the-whole-universe-agree-on-the-laws-of-physics
# https://mathoverflow.net/questions/374921/are-generators-defined-in-tohoku-paper-equivalent-to-that-defined-in-wikipedia
# https://french.stackexchange.com/questions/43397/meaning-of-porte-qui-claque
# https://outdoors.stackexchange.com/questions/25581/giving-honey-to-a-bear
# https://ell.stackexchange.com/questions/264480/why-does-elite-rhyme-with-beet-rather-than-bite
# https://codegolf.stackexchange.com/questions/214077/implement-smokeys-alive-command
# https://politics.stackexchange.com/questions/59375/are-democratic-members-of-congress-more-educated
# https://worldbuilding.stackexchange.com/questions/188871/are-dragons-useless-when-there-are-guns
# https://rpg.stackexchange.com/questions/176831/is-there-anything-preventing-a-wizard-from-using-a-staff-of-healing
# https://literature.stackexchange.com/questions/16087/whats-the-deal-with-bilbo-being-some-kind-of-burglar
# https://rpg.stackexchange.com/questions/176823/does-blink-grant-advantage-on-the-first-attack-roll-after-you-return
# https://law.stackexchange.com/questions/57474/is-wearing-aclus-let-people-vote-pin-to-the-polling-place-considered-election
# https://scifi.stackexchange.com/questions/238458/has-the-star-trek-away-team-ever-beamed-down-to-a-planet-with-significantly-high
# https://codereview.stackexchange.com/questions/251123/event-tracking-system
# https://quantumcomputing.stackexchange.com/questions/14345/creating-a-custom-gate-given-by-a-matrix-more-efficiently
# https://unix.stackexchange.com/questions/616527/creating-a-new-user-breaking-existing-permissions
# https://bicycles.stackexchange.com/questions/72949/how-practical-are-clipless-pedal-shoes-on-a-long-bike-tour
# https://skeptics.stackexchange.com/questions/49698/did-the-house-select-committee-on-assassinations-come-to-the-conclusion-that-jfk
# https://politics.stackexchange.com/questions/59387/why-is-the-economist-model-so-sure-trump-is-going-to-lose-compared-to-other-mode
# https://stackoverflow.com/questions/64527951/why-is-stdpair-from-anonymous-object-copying-that-object-instead-of-moving
# https://physics.stackexchange.com/questions/589772/does-the-bell-test-preclude-localism-realism-both-or-just-one-of-either-inde
# #
# https://stackoverflow.com
# https://stackoverflow.com
# /questions
# https://stackoverflow.com/jobs
# https://stackoverflow.com/jobs/directory/developer-jobs
# https://stackoverflow.com/jobs/salary
# /help
# None
# https://stackoverflowbusiness.com
# https://stackoverflow.com/teams
# https://stackoverflow.com/talent
# https://stackoverflow.com/advertising
# https://stackoverflow.com/enterprise
# https://stackoverflow.com/company
# https://stackoverflow.com/company
# https://stackoverflow.com/company/press
# https://stackoverflow.com/company/work-here
# https://stackoverflow.com/legal
# https://stackoverflow.com/legal/privacy-policy
# https://stackoverflow.com/company/contact
# #
# https://stackexchange.com
# #
# #
# #
# #
# #
# https://stackoverflow.com
# https://serverfault.com
# https://superuser.com
# https://webapps.stackexchange.com
# https://askubuntu.com
# https://webmasters.stackexchange.com
# https://gamedev.stackexchange.com
# https://tex.stackexchange.com
# https://softwareengineering.stackexchange.com
# https://unix.stackexchange.com
# https://apple.stackexchange.com
# https://wordpress.stackexchange.com
# https://gis.stackexchange.com
# https://electronics.stackexchange.com
# https://android.stackexchange.com
# https://security.stackexchange.com
# https://dba.stackexchange.com
# https://drupal.stackexchange.com
# https://sharepoint.stackexchange.com
# https://ux.stackexchange.com
# https://mathematica.stackexchange.com
# https://salesforce.stackexchange.com
# https://expressionengine.stackexchange.com
# https://pt.stackoverflow.com
# https://blender.stackexchange.com
# https://networkengineering.stackexchange.com
# https://crypto.stackexchange.com
# https://codereview.stackexchange.com
# https://magento.stackexchange.com
# https://softwarerecs.stackexchange.com
# https://dsp.stackexchange.com
# https://emacs.stackexchange.com
# https://raspberrypi.stackexchange.com
# https://ru.stackoverflow.com
# https://codegolf.stackexchange.com
# https://es.stackoverflow.com
# https://ethereum.stackexchange.com
# https://datascience.stackexchange.com
# https://arduino.stackexchange.com
# https://bitcoin.stackexchange.com
# https://sqa.stackexchange.com
# https://sound.stackexchange.com
# https://windowsphone.stackexchange.com
# https://stackexchange.com/sites#technology
# https://photo.stackexchange.com
# https://scifi.stackexchange.com
# https://graphicdesign.stackexchange.com
# https://movies.stackexchange.com
# https://music.stackexchange.com
# https://worldbuilding.stackexchange.com
# https://video.stackexchange.com
# https://cooking.stackexchange.com
# https://diy.stackexchange.com
# https://money.stackexchange.com
# https://academia.stackexchange.com
# https://law.stackexchange.com
# https://fitness.stackexchange.com
# https://gardening.stackexchange.com
# https://parenting.stackexchange.com
# https://stackexchange.com/sites#lifearts
# https://english.stackexchange.com
# https://skeptics.stackexchange.com
# https://judaism.stackexchange.com
# https://travel.stackexchange.com
# https://christianity.stackexchange.com
# https://ell.stackexchange.com
# https://japanese.stackexchange.com
# https://chinese.stackexchange.com
# https://french.stackexchange.com
# https://german.stackexchange.com
# https://hermeneutics.stackexchange.com
# https://history.stackexchange.com
# https://spanish.stackexchange.com
# https://islam.stackexchange.com
# https://rus.stackexchange.com
# https://russian.stackexchange.com
# https://gaming.stackexchange.com
# https://bicycles.stackexchange.com
# https://rpg.stackexchange.com
# https://anime.stackexchange.com
# https://puzzling.stackexchange.com
# https://mechanics.stackexchange.com
# https://boardgames.stackexchange.com
# https://bricks.stackexchange.com
# https://homebrew.stackexchange.com
# https://martialarts.stackexchange.com
# https://outdoors.stackexchange.com
# https://poker.stackexchange.com
# https://chess.stackexchange.com
# https://sports.stackexchange.com
# https://stackexchange.com/sites#culturerecreation
# https://mathoverflow.net
# https://math.stackexchange.com
# https://stats.stackexchange.com
# https://cstheory.stackexchange.com
# https://physics.stackexchange.com
# https://chemistry.stackexchange.com
# https://biology.stackexchange.com
# https://cs.stackexchange.com
# https://philosophy.stackexchange.com
# https://linguistics.stackexchange.com
# https://psychology.stackexchange.com
# https://scicomp.stackexchange.com
# https://stackexchange.com/sites#science
# https://meta.stackexchange.com
# https://stackapps.com
# https://api.stackexchange.com
# https://data.stackexchange.com
# https://stackoverflow.blog?blb=1
# https://www.facebook.com/officialstackoverflow/
# https://twitter.com/stackoverflow
# https://linkedin.com/company/stack-overflow
# https://www.instagram.com/thestackoverflow
# https://stackoverflow.com/help/licensing
# /
# /questions
# /tags
# /users
# /jobs?so_medium=StackOverflow&so_source=SiteNav
# /jobs/companies?so_medium=StackOverflow&so_source=SiteNav
# javascript:void(0)
# https://stackoverflow.com/teams
#
#                     By using our site, you acknowledge that you have read and understand our Cookie Policy, Privacy Policy, and our Terms of Service.
#
# Teams
# Q&A for Work
#
#
#                             Stack Overflow for Teams is a private, secure spot for you and
#                             your coworkers to find and share information.
#
#
# site design / logo © 2020 Stack Exchange Inc; user contributions licensed under cc by-sa.                    rev 2020.10.26.37891
# it will be contunued
